# %%
#change working directory, for moduls of other package
import os
os.chdir(os.path.abspath('../../../00_src'))

# %%
import sys
import numpy as np
from agents.agent_ollama import AgentOllama
from environment.environment import SokobanEnvImpl
import environment.util as env_util
import environment.const as env_const
import environment.visualization as env_vis
from knowledge_graph.knowledge_graph import KnowledgeGraph
# %matplotlib inline

# %%
attempt = 6
UP, DOWN, LEFT, RIGHT = env_const.UP, env_const.DOWN, env_const.LEFT, env_const.RIGHT
WALL, FLOOR, BOX_TARGET, BOX_ON_TARGET, BOX, PLAYER = env_const.WALL, env_const.FLOOR, env_const.BOX_TARGET, env_const.BOX_ON_TARGET, env_const.BOX, env_const.PLAYER
env = SokobanEnvImpl(max_steps=60, use_default_env=True)
kg = KnowledgeGraph(env)

# %%
agent_player = AgentOllama("qwen3:8b",
                     [("system", ("You are an agent who plays the game Sokoban. \n"
                                  "The target of the PLAYER is to push every BOX on top of a BOX_TARGET, with as few steps as possible. \n"
                                  "Current game state [0:WALL, 1:FLOOR, 2:BOX_TARGET, 3:BOX_ON_TARGET, 4:BOX, 5:PLAYER]: \n"
                                  "{game_state} \n"
                                  "Answer only in one word with one of the following possible actions {possible_actions}.")),        
                      ("human", ("The optimal path to solve is {shortest_trajectory}. What is the next action?"))])
agent_player.write_log("../03_resource/09_LLM_KG/output/default_env_{:02}_attempt_trajectory.log".format(attempt), clear_log_path=True)

# %%
room_caption_map = {WALL:"WALL", FLOOR:"FLOOR", BOX_TARGET:"BOX_TARGET", BOX_ON_TARGET:"BOX_ON_TARGET", BOX:"BOX", PLAYER:"PLAYER"}
action_caption_map = {0: "WAIT", UP:"UP", DOWN:"DOWN", LEFT:"LEFT", RIGHT:"RIGHT"}
caption_action_map = {"UP":UP, "DOWN":DOWN, "LEFT":LEFT, "RIGHT":RIGHT}

def create_input():
    game_state = env.room_state
    shortest_trajectory = np.array2string(np.vectorize(action_caption_map.get)(env_util.breadth_first_search(env)), max_line_width=sys.maxsize)
    possible_actions = np.vectorize(action_caption_map.get)(kg.get_possible_actions())
    return {"game_state": game_state,
            "shortest_trajectory" : shortest_trajectory,
            "possible_actions": possible_actions}

def doStep(step:int) -> bool:
    observation, reward_last, done, info = env.step(step)
    kg.update()
    return done

# %%
done = False
trajectory = []

while not done:
    agent_answer = agent_player.invoke(create_input()).split("</think>", 1)
    agent_answer = agent_answer[1] if len(agent_answer) > 1 else ""
    next_action = 0 # default do nothing
    print("Step {step}: Action ".format(step = len(trajectory)+1), end= "")
    for action_id in caption_action_map.keys():
        if action_id in agent_answer:
            print(action_id, end="") if next_action == 0 else print(", " + action_id, end="")
            next_action = caption_action_map.get(action_id)
    print()
    trajectory.append(next_action)
    done = doStep(next_action)

env.reset()
# Out:
# Step 1: Action RIGHT
# Step 2: Action RIGHT
# Step 3: Action RIGHT
# Step 4: Action LEFT
# Step 5: Action RIGHT
# Step 6: Action RIGHT
# Step 7: Action LEFT
# Step 8: Action DOWN
# Step 9: Action LEFT
# Step 10: Action LEFT
# Step 11: Action LEFT
# Step 12: Action LEFT
# Step 13: Action DOWN
# Step 14: Action LEFT
# Step 15: Action LEFT
# Step 16: Action DOWN
# Step 17: Action DOWN
# Step 18: Action RIGHT
# Step 19: Action
# Step 20: Action UP
# Step 21: Action LEFT
# Step 22: Action UP
# Step 23: Action UP
# Step 24: Action RIGHT
# Step 25: Action RIGHT
# Step 26: Action DOWN
# Step 27: Action LEFT
# Step 28: Action UP, DOWN, LEFT, RIGHT
# Step 29: Action UP
# Step 30: Action
# Step 31: Action
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 trajectory = []
#       4 while not done:
# ----> 5     agent_answer = agent_player.invoke(create_input()).split("</think>", 1)
#       6     agent_answer = agent_answer[1] if len(agent_answer) > 1 else ""
#       7     next_action = 0 # default do nothing
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\00_src\agents\agent_ollama.py:23, in AgentOllama.invoke(self, message)
#      21 def invoke(self, message: Sequence) -> str:
#      22     self.logger.info(self.prompt.invoke(message))
# ---> 23     answer = self.chain.invoke(message)
#      24     self.logger.info([answer])
#      25     return answer.content
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\runnables\base.py:3034, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3032                 input = context.run(step.invoke, input, config, **kwargs)
#    3033             else:
# -> 3034                 input = context.run(step.invoke, input, config)
#    3035 # finish the root run
#    3036 except BaseException as e:
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\runnables\base.py:4757, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4743 """Invoke this Runnable synchronously.
#    4744
#    4745 Args:
#    (...)
#    4754     TypeError: If the Runnable is a coroutine function.
#    4755 """
#    4756 if hasattr(self, "func"):
# -> 4757     return self._call_with_config(
#    4758         self._invoke,
#    4759         input,
#    4760         ensure_config(config),
#    4761         **kwargs,
#    4762     )
#    4763 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4764 raise TypeError(msg)
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\runnables\base.py:1930, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1926     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1927     with set_config_context(child_config) as context:
#    1928         output = cast(
#    1929             "Output",
# -> 1930             context.run(
#    1931                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1932                 func,
#    1933                 input,
#    1934                 config,
#    1935                 run_manager,
#    1936                 **kwargs,
#    1937             ),
#    1938         )
#    1939 except BaseException as e:
#    1940     run_manager.on_chain_error(e)
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\runnables\base.py:4615, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    4613                 output = chunk
#    4614 else:
# -> 4615     output = call_func_with_variable_args(
#    4616         self.func, input, config, run_manager, **kwargs
#    4617     )
#    4618 # If the output is a Runnable, invoke it
#    4619 if isinstance(output, Runnable):
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\language_models\chat_models.py:370, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     358 @override
#     359 def invoke(
#     360     self,
#    (...)
#     365     **kwargs: Any,
#     366 ) -> BaseMessage:
#     367     config = ensure_config(config)
#     368     return cast(
#     369         "ChatGeneration",
# --> 370         self.generate_prompt(
#     371             [self._convert_input(input)],
#     372             stop=stop,
#     373             callbacks=config.get("callbacks"),
#     374             tags=config.get("tags"),
#     375             metadata=config.get("metadata"),
#     376             run_name=config.get("run_name"),
#     377             run_id=config.pop("run_id", None),
#     378             **kwargs,
#     379         ).generations[0][0],
#     380     ).message
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\language_models\chat_models.py:947, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     938 @override
#     939 def generate_prompt(
#     940     self,
#    (...)
#     944     **kwargs: Any,
#     945 ) -> LLMResult:
#     946     prompt_messages = [p.to_messages() for p in prompts]
# --> 947     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\language_models\chat_models.py:766, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     763 for i, m in enumerate(input_messages):
#     764     try:
#     765         results.append(
# --> 766             self._generate_with_cache(
#     767                 m,
#     768                 stop=stop,
#     769                 run_manager=run_managers[i] if run_managers else None,
#     770                 **kwargs,
#     771             )
#     772         )
#     773     except BaseException as e:
#     774         if run_managers:
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1012, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1010     result = generate_from_stream(iter(chunks))
#    1011 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1012     result = self._generate(
#    1013         messages, stop=stop, run_manager=run_manager, **kwargs
#    1014     )
#    1015 else:
#    1016     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_ollama\chat_models.py:715, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     708 def _generate(
#     709     self,
#     710     messages: list[BaseMessage],
#    (...)
#     713     **kwargs: Any,
#     714 ) -> ChatResult:
# --> 715     final_chunk = self._chat_stream_with_aggregation(
#     716         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     717     )
#     718     generation_info = final_chunk.generation_info
#     719     chat_generation = ChatGeneration(
#     720         message=AIMessage(
#     721             content=final_chunk.text,
#    (...)
#     726         generation_info=generation_info,
#     727     )
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_ollama\chat_models.py:652, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     643 def _chat_stream_with_aggregation(
#     644     self,
#     645     messages: list[BaseMessage],
#    (...)
#     649     **kwargs: Any,
#     650 ) -> ChatGenerationChunk:
#     651     final_chunk = None
# --> 652     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     653         if final_chunk is None:
#     654             final_chunk = chunk
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_ollama\chat_models.py:737, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     730 def _iterate_over_stream(
#     731     self,
#     732     messages: list[BaseMessage],
#     733     stop: Optional[list[str]] = None,
#     734     **kwargs: Any,
#     735 ) -> Iterator[ChatGenerationChunk]:
#     736     is_thinking = False
# --> 737     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     738         if not isinstance(stream_resp, str):
#     739             if stream_resp.get("done") is True:
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\langchain_ollama\chat_models.py:639, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     636 chat_params = self._chat_params(messages, stop, **kwargs)
#     638 if chat_params["stream"]:
# --> 639     yield from self._client.chat(**chat_params)
#     640 else:
#     641     yield self._client.chat(**chat_params)
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\ollama\_client.py:170, in Client._request.<locals>.inner()
#     167   e.response.read()
#     168   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 170 for line in r.iter_lines():
#     171   part = json.loads(line)
#     172   if err := part.get('error'):
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpx\_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpx\_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\roger.naef\Documents\vm-code-generation-with-knowledge-graph\venv\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
trajectory_of_moves = [action for action in trajectory if action != 0]
env_vis.animate(env=env, path=trajectory_of_moves, save_ani="../03_resource/09_LLM_KG/output/default_env_{:02}_attempt_trajectory.gif".format(attempt), dpi=300)
