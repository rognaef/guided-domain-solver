# %%
from gym_sokoban.envs import SokobanEnv
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#imports from other directory
import sys, os
sys.path.insert(0, os.path.abspath('../../00_src'))
from knowledge_graph.knowledge_graph import KnowledgeGraph
del sys.path[0]

# %%
import logging
logger = logging.getLogger("Neo4jClient")
logger.setLevel('INFO')
logger.addHandler(logging.StreamHandler(sys.stdout))

# %%
env = SokobanEnv(dim_room=(6, 6), max_steps=40, num_boxes=3, num_gen_steps=None, reset=True)

def render_state(env, mode="rgb_array"):
    """Renders the Sokoban environment as image and displays it."""
    image = env.render(mode)

    plt.figure(dpi=200) 
    plt.imshow(image)
    plt.axis('off')
    plt.show()

render_state(env)

# %%
kg = KnowledgeGraph(env)
# Out:
# cleared all nodes in neo4j
# successful write:CREATE (:Floor {id: 1, x:2, y:1, has_box_target:True, tag:"Floor [2,1]"}),(:Floor {id: 2, x:3, y:1, has_box_target:False, tag:"Floor [3,1]"}),(:Floor {id: 3, x:4, y:1, has_box_target:False, tag:"Floor [4,1]"}),(:Floor {id: 4, x:1, y:2, has_box_target:False, tag:"Floor [1,2]"}),(:Floor {id: 5, x:2, y:2, has_box_target:False, tag:"Floor [2,2]"}),(:Floor {id: 6, x:3, y:2, has_box_target:False, tag:"Floor [3,2]"}),(:Floor {id: 7, x:4, y:2, has_box_target:False, tag:"Floor [4,2]"}),(:Floor {id: 8, x:1, y:3, has_box_target:False, tag:"Floor [1,3]"}),(:Floor {id: 9, x:2, y:3, has_box_target:False, tag:"Floor [2,3]"}),(:Floor {id: 10, x:3, y:3, has_box_target:False, tag:"Floor [3,3]"}),(:Floor {id: 11, x:4, y:3, has_box_target:True, tag:"Floor [4,3]"}),(:Floor {id: 12, x:1, y:4, has_box_target:False, tag:"Floor [1,4]"}),(:Floor {id: 13, x:2, y:4, has_box_target:True, tag:"Floor [2,4]"}),(:Floor {id: 14, x:3, y:4, has_box_target:False, tag:"Floor [3,4]"}),(:Floor {id: 15, x:4, y:4, has_box_target:False, tag:"Floor [4,4]"});
# successful write:MATCH (o1:Floor),(o2:Floor) WHERE (o1.x = o2.x AND o1.y = o2.y-1) OR (o1.x = o2.x AND o1.y = o2.y+1) OR (o1.x = o2.x-1 AND o1.y = o2.y) OR (o1.x = o2.x+1 AND o1.y = o2.y) CREATE (o1)-[:CAN_GO_TO]->(o2);
# successful write:CREATE (:Box {id: 1, x:2, y:3, is_on_target:False, tag:"Box"}),(:Box {id: 2, x:3, y:3, is_on_target:False, tag:"Box"}),(:Box {id: 3, x:3, y:4, is_on_target:False, tag:"Box"}),(:Player {id: 1, x:4, y:4, tag:"Player"});
# successful write:MATCH (b:Box),(f:Floor) WHERE (b.x = 3 AND b.y = 3 AND f.x = 2 AND f.y = 1) OR (b.x = 2 AND b.y = 3 AND f.x = 4 AND f.y = 3) OR (b.x = 3 AND b.y = 4 AND f.x = 2 AND f.y = 4) CREATE (b)-[:SHOULD_GO_TO]->(f);
# successful write:MATCH (p:Player),(f:Floor) WHERE p.x = f.x AND p.y = f.y CREATE (p)-[:ON_TOP_OF]->(f);
# successful write:MATCH (b:Box),(f:Floor) WHERE b.x = f.x AND b.y = f.y CREATE (b)-[:ON_TOP_OF]->(f);
# successful write:CREATE (:Action {id: 1, dx:0, dy:-1, tag:"Up"}),(:Action {id: 3, dx:-1, dy:0, tag:"Left"});
# successful write:MATCH (p:Player),(a:Action) CREATE (p)-[:CAN_MOVE]->(a);

# %%
UP, DOWN, LEFT, RIGHT = 1, 2, 3, 4
def doStep(step):
    env.step(step)
    render_state(env)
    kg.update()

# %%
doStep(LEFT)
# Out:
# successful write:MATCH () -[r:ON_TOP_OF] -> () DELETE r
# successful write:MATCH () -[r:CAN_MOVE] -> () DELETE r
# successful write:MATCH (a:Action) DELETE a
# successful write:MATCH (p:Player {id: 1}) SET p += {x: 3, y: 4} RETURN p
# successful read: MATCH (b:Box) RETURN b
# successful write:MATCH (b:Box {id: 3}) SET b += {x: 2, y: 4} RETURN b
# successful write:MATCH (p:Player),(f:Floor) WHERE p.x = f.x AND p.y = f.y CREATE (p)-[:ON_TOP_OF]->(f);
# successful write:MATCH (b:Box),(f:Floor) WHERE b.x = f.x AND b.y = f.y CREATE (b)-[:ON_TOP_OF]->(f);
# successful write:CREATE (:Action {id: 1, dx:0, dy:-1, tag:"Up"}),(:Action {id: 3, dx:-1, dy:0, tag:"Left"}),(:Action {id: 4, dx:1, dy:0, tag:"Right"});
# successful write:MATCH (p:Player),(a:Action) CREATE (p)-[:CAN_MOVE]->(a);
